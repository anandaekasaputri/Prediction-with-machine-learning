# %% [markdown]
# # Import Data

# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd
from google.colab import files
data = files.upload()
# Out:
#      <input type="file" id="files-38920eaa-e45f-4991-ba62-c047db9907e2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-38920eaa-e45f-4991-ba62-c047db9907e2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving student-mat.csv to student-mat.csv

# %%
data = pd.read_csv('student-mat.csv')

# %% [markdown]
# # Eksplorasi dan Preprocessing Data

# %%
data.head(n=5)
# Out:
#   school sex  age address famsize Pstatus  ...  Walc  health absences  G1  G2  G3
# 0     GP   F   18       U     GT3       A  ...     1       3        6   5   6   6
# 1     GP   F   17       U     GT3       T  ...     1       3        4   5   5   6
# 2     GP   F   15       U     LE3       T  ...     3       3       10   7   8  10
# 3     GP   F   15       U     GT3       T  ...     1       5        2  15  14  15
# 4     GP   F   16       U     GT3       T  ...     2       5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
data.tail(n=5)
# Out:
#     school sex  age address famsize Pstatus  ...  Walc  health absences  G1  G2  G3
# 390     MS   M   20       U     LE3       A  ...     5       4       11   9   9   9
# 391     MS   M   17       U     LE3       T  ...     4       2        3  14  16  16
# 392     MS   M   21       R     GT3       T  ...     3       3        3  10   8   7
# 393     MS   M   18       R     LE3       T  ...     4       5        0  11  12  10
# 394     MS   M   19       U     LE3       T  ...     3       5        5   8   9   9
#
# [5 rows x 33 columns]

# %%
correlation_matrix=data.corr()
correlation_matrix['G3']
# Out:
# school              -0.045017
# sex                  0.103456
# age                 -0.161579
# address              0.105756
# famsize              0.081407
# Pstatus             -0.058009
# Medu                 0.217147
# Fedu                 0.152457
# traveltime          -0.117142
# studytime            0.097820
# failures            -0.360415
# schoolsup           -0.082788
# famsup              -0.039157
# paid                 0.101996
# activities           0.016100
# nursery              0.051568
# higher               0.182465
# internet             0.098483
# romantic            -0.129970
# famrel               0.051363
# freetime             0.011307
# goout               -0.132791
# Dalc                -0.054660
# Walc                -0.051939
# health              -0.061335
# absences             0.034247
# G1                   0.801468
# G2                   0.904868
# G3                   1.000000
# Mjob_at_home        -0.115634
# Mjob_health          0.116158
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
# ...

# %% [markdown]
# **Numerical Coloumn**
# - age
# - Medu
# - Fedu
# - traveltime
# - studytime
# - Failures
# - famrel
# - freetime
# - goout
# - Dalc
# - Walc
# - health
# - absences
# - G1
# - G2
# - G3
#
# **Binary Coloumn**
# - school
# - sex
# - address
# - famsize
# - Pstatus
# - schoolsup
# - famsup
# - paid
# - activities
# - nursery
# - higher
# - internet
# - romantic
#
# **Categorical columns to convert to dummy columns**
# - Mjob
# - Fjob
# - reason
# - guardian

# %%
data.describe()
# Out:
#               age        Medu        Fedu  ...          G1          G2          G3
# count  395.000000  395.000000  395.000000  ...  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519  ...   10.908861   10.713924   10.415190
# std      1.276043    1.094735    1.088201  ...    3.319195    3.761505    4.581443
# min     15.000000    0.000000    0.000000  ...    3.000000    0.000000    0.000000
# 25%     16.000000    2.000000    2.000000  ...    8.000000    9.000000    8.000000
# 50%     17.000000    3.000000    2.000000  ...   11.000000   11.000000   11.000000
# 75%     18.000000    4.000000    3.000000  ...   13.000000   13.000000   14.000000
# max     22.000000    4.000000    4.000000  ...   19.000000   19.000000   20.000000
#
# [8 rows x 16 columns]

# %%
data.nunique()
# Out:
# school         2
# sex            2
# age            8
# address        2
# famsize        2
# Pstatus        2
# Medu           5
# Fedu           5
# Mjob           5
# Fjob           5
# reason         4
# guardian       3
# traveltime     4
# studytime      4
# failures       4
# schoolsup      2
# famsup         2
# paid           2
# activities     2
# nursery        2
# higher         2
# internet       2
# romantic       2
# famrel         5
# freetime       5
# goout          5
# Dalc           5
# Walc           5
# health         5
# absences      34
# G1            17
# G2            17
# G3            18
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10,5))
sns.heatmap(data.isnull(), cbar=False, yticklabels=False, cmap="viridis")

# %%
data.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
feats = data.drop('G3', axis=1)
target = data[['G3']]
print(f'Features table has {feats.shape[0]} rows and {feats.shape[1]} columns')
print(f'Target table has {target.shape[0]} rows')
# Out:
# Features table has 395 rows and 32 columns
# Target table has 395 rows

# %%
data.select_dtypes(include=['int64', 'float64']).hist(figsize=(16,16))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f9477e3fa90>,
# ...
#       dtype=object)

# %%
plt.figure(figsize=(5,5))
data['school'].value_counts().plot.pie(explode=[0,0.1], autopct='%1.2f%%')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(5,5))
data['sex'].value_counts().plot.pie(explode=[0,0.1], autopct='%1.2f%%')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(5,5))
data['address'].value_counts().plot.pie(explode=[0,0.1], autopct='%1.2f%%')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(5,5))
data['famsize'].value_counts().plot.pie(explode=[0,0.1], autopct='%1.2f%%')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(5,5))
data['Pstatus'].value_counts().plot.pie(explode=[0,0.1], autopct='%1.2f%%')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(5,5))
data['schoolsup'].value_counts().plot.pie(explode=[0,0.1], autopct='%1.2f%%')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(5,5))
data['famsup'].value_counts().plot.pie(explode=[0,0.1], autopct='%1.2f%%')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(5,5))
data['paid'].value_counts().plot.pie(explode=[0,0.1], autopct='%1.2f%%')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(5,5))
data['activities'].value_counts().plot.pie(explode=[0,0.1], autopct='%1.2f%%')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(5,5))
data['nursery'].value_counts().plot.pie(explode=[0,0.1], autopct='%1.2f%%')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(5,5))
data['higher'].value_counts().plot.pie(explode=[0,0.1], autopct='%1.2f%%')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(5,5))
data['internet'].value_counts().plot.pie(explode=[0,0.1], autopct='%1.2f%%')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(5,5))
data['romantic'].value_counts().plot.pie(explode=[0,0.1], autopct='%1.2f%%')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(5,5))
data['Mjob'].value_counts().plot.bar()
plt.show()

# %%
plt.figure(figsize=(5,5))
data['Fjob'].value_counts().plot.bar()
plt.show()

# %%
plt.figure(figsize=(5,5))
data['reason'].value_counts().plot.bar()
plt.show()

# %%
plt.figure(figsize=(5,5))
data['guardian'].value_counts().plot.bar()
plt.show()

# %% [markdown]
# # Encoding Variables

# %%
from sklearn.preprocessing import LabelEncoder

num_cols = ['age', 'Medu', 'Fedu', 'traveltime', 'studytime', 'failures', 'famrel', 'freetime', 'goout', 'Dalc', 'Walc', 'health', 'absences', 'G1', 'G2', 'G3']
bin_cols = ['school', 'sex', 'address', 'famsize', 'Pstatus', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery', 'higher', 'internet', 'romantic']
multi_cols = ['Mjob', 'Fjob', 'reason', 'guardian']

le = LabelEncoder()
for i in bin_cols :
  data[i] = le.fit_transform(data[i])

data=pd.get_dummies(data = data, columns = multi_cols, drop_first=False)

# %%
data
# Out:
#      school  sex  age  ...  guardian_father  guardian_mother  guardian_other
# 0         0    0   18  ...                0                1               0
# 1         0    0   17  ...                1                0               0
# 2         0    0   15  ...                0                1               0
# 3         0    0   15  ...                0                1               0
# 4         0    0   16  ...                1                0               0
# ..      ...  ...  ...  ...              ...              ...             ...
# 390       1    1   20  ...                0                0               1
# 391       1    1   17  ...                0                1               0
# 392       1    1   21  ...                0                0               1
# 393       1    1   18  ...                0                1               0
# 394       1    1   19  ...                1                0               0
#
# [395 rows x 46 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 46 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   school             395 non-null    int64
#  1   sex                395 non-null    int64
#  2   age                395 non-null    int64
#  3   address            395 non-null    int64
#  4   famsize            395 non-null    int64
#  5   Pstatus            395 non-null    int64
#  6   Medu               395 non-null    int64
#  7   Fedu               395 non-null    int64
#  8   traveltime         395 non-null    int64
#  9   studytime          395 non-null    int64
#  10  failures           395 non-null    int64
#  11  schoolsup          395 non-null    int64
#  12  famsup             395 non-null    int64
#  13  paid               395 non-null    int64
#  14  activities         395 non-null    int64
#  15  nursery            395 non-null    int64
# ...

# %% [markdown]
# # Data Partition

# %% [markdown]
# data -> data dengan G1 dan G2 tetap ada
#
# data_1 -> data dengan G1 dan G2 dikeluarkan
#
# data_2 -> data dengan G1 dikeluarkan, G2 tetap ada
#
# data_3 -> data dengan G2 dikeluarkan dan G1 tetap ada

# %%
from sklearn.model_selection import train_test_split

train,test = train_test_split(data, test_size = 0.2, random_state = 111)

train_X = train.drop(labels='G3', axis=1)
train_Y = train['G3']
test_X = test.drop(labels='G3', axis=1)
test_Y = test['G3']

# %%
##data_1
train_X1 = train_X.drop(labels=['G1', 'G2'], axis=1)
train_Y1 = train['G3']
test_X1 = test_X.drop(labels=['G1', 'G2'], axis=1)
test_Y1 = test['G3']

##data_2
train_X2 = train_X.drop(labels='G1', axis=1)
train_Y2 = train['G3']
test_X2 = test_X.drop(labels='G1', axis=1)
test_Y2 = test['G3']

##data_3
train_X3 = train_X.drop(labels='G2', axis=1)
train_Y3 = train['G3']
test_X3 = test_X.drop(labels='G2', axis=1)
test_Y3 = test['G3']

# %%
train_X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 316 entries, 388 to 340
# Data columns (total 45 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   school             316 non-null    int64
#  1   sex                316 non-null    int64
#  2   age                316 non-null    int64
#  3   address            316 non-null    int64
#  4   famsize            316 non-null    int64
#  5   Pstatus            316 non-null    int64
#  6   Medu               316 non-null    int64
#  7   Fedu               316 non-null    int64
#  8   traveltime         316 non-null    int64
#  9   studytime          316 non-null    int64
#  10  failures           316 non-null    int64
#  11  schoolsup          316 non-null    int64
#  12  famsup             316 non-null    int64
#  13  paid               316 non-null    int64
#  14  activities         316 non-null    int64
#  15  nursery            316 non-null    int64
# ...

# %%
train_X1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 316 entries, 388 to 340
# Data columns (total 43 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   school             316 non-null    int64
#  1   sex                316 non-null    int64
#  2   age                316 non-null    int64
#  3   address            316 non-null    int64
#  4   famsize            316 non-null    int64
#  5   Pstatus            316 non-null    int64
#  6   Medu               316 non-null    int64
#  7   Fedu               316 non-null    int64
#  8   traveltime         316 non-null    int64
#  9   studytime          316 non-null    int64
#  10  failures           316 non-null    int64
#  11  schoolsup          316 non-null    int64
#  12  famsup             316 non-null    int64
#  13  paid               316 non-null    int64
#  14  activities         316 non-null    int64
#  15  nursery            316 non-null    int64
# ...

# %%
train_X2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 316 entries, 388 to 340
# Data columns (total 44 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   school             316 non-null    int64
#  1   sex                316 non-null    int64
#  2   age                316 non-null    int64
#  3   address            316 non-null    int64
#  4   famsize            316 non-null    int64
#  5   Pstatus            316 non-null    int64
#  6   Medu               316 non-null    int64
#  7   Fedu               316 non-null    int64
#  8   traveltime         316 non-null    int64
#  9   studytime          316 non-null    int64
#  10  failures           316 non-null    int64
#  11  schoolsup          316 non-null    int64
#  12  famsup             316 non-null    int64
#  13  paid               316 non-null    int64
#  14  activities         316 non-null    int64
#  15  nursery            316 non-null    int64
# ...

# %%
train_X3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 316 entries, 388 to 340
# Data columns (total 44 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   school             316 non-null    int64
#  1   sex                316 non-null    int64
#  2   age                316 non-null    int64
#  3   address            316 non-null    int64
#  4   famsize            316 non-null    int64
#  5   Pstatus            316 non-null    int64
#  6   Medu               316 non-null    int64
#  7   Fedu               316 non-null    int64
#  8   traveltime         316 non-null    int64
#  9   studytime          316 non-null    int64
#  10  failures           316 non-null    int64
#  11  schoolsup          316 non-null    int64
#  12  famsup             316 non-null    int64
#  13  paid               316 non-null    int64
#  14  activities         316 non-null    int64
#  15  nursery            316 non-null    int64
# ...

# %%
train_X.describe()
# Out:
#            school         sex  ...  guardian_mother  guardian_other
# count  316.000000  316.000000  ...       316.000000      316.000000
# mean     0.123418    0.471519  ...         0.686709        0.072785
# std      0.329438    0.499980  ...         0.464567        0.260195
# min      0.000000    0.000000  ...         0.000000        0.000000
# 25%      0.000000    0.000000  ...         0.000000        0.000000
# 50%      0.000000    0.000000  ...         1.000000        0.000000
# 75%      0.000000    1.000000  ...         1.000000        0.000000
# max      1.000000    1.000000  ...         1.000000        1.000000
#
# [8 rows x 45 columns]

# %%
train_Y.describe()
# Out:
# count    316.000000
# mean      10.490506
# std        4.645179
# min        0.000000
# 25%        9.000000
# 50%       11.000000
# 75%       14.000000
# max       20.000000
# Name: G3, dtype: float64

# %%
test_X.describe()
# Out:
#           school        sex  ...  guardian_mother  guardian_other
# count  79.000000  79.000000  ...        79.000000       79.000000
# mean    0.088608   0.481013  ...         0.708861        0.113924
# std     0.285992   0.502832  ...         0.457190        0.319749
# min     0.000000   0.000000  ...         0.000000        0.000000
# 25%     0.000000   0.000000  ...         0.000000        0.000000
# 50%     0.000000   0.000000  ...         1.000000        0.000000
# 75%     0.000000   1.000000  ...         1.000000        0.000000
# max     1.000000   1.000000  ...         1.000000        1.000000
#
# [8 rows x 45 columns]

# %%
test_Y.describe()
# Out:
# count    79.000000
# mean     10.113924
# std       4.332310
# min       0.000000
# 25%       8.000000
# 50%      11.000000
# 75%      13.000000
# max      18.000000
# Name: G3, dtype: float64

# %% [markdown]
# # Data Imbalance

# %%
from imblearn.over_sampling import SMOTE

os = SMOTE(sampling_strategy='minority', random_state = 123, k_neighbors=0)
train_smote_X, train_smote_Y = os.fit_resample(train_X,train_Y)
train_smote_X = pd.DataFrame(data=train_smote_X, columns=train_X.columns)
train_smote_Y = pd.DataFreame(data=train_smote_Y)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-75-b3cf8aa6e3a1> in <module>()
#       2
#       3 os = SMOTE(sampling_strategy='minority', random_state = 123, k_neighbors=0)
# ----> 4 train_smote_X, train_smote_Y = os.fit_resample(train_X,train_Y)
#       5 train_smote_X = pd.DataFrame(data=train_smote_X, columns=train_X.columns)
#       6 train_smote_Y = pd.DataFreame(data=train_smote_Y)
#
# /usr/local/lib/python3.7/dist-packages/imblearn/base.py in fit_resample(self, X, y)
#      83             self.sampling_strategy, y, self._sampling_type)
#      84
# ---> 85         output = self._fit_resample(X, y)
# ...

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
modelRFC=RandomForestRegressor()
modelRFC.fit(train_X,train_Y)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
#get importance
impRFC = modelRFC.feature_importances_
print("importances feature Data")
for i,v in enumerate(impRFC):
  print("Feature : %0d, Score: %.5f" % (i,v))
# Out:
# importances feature Data
# Feature : 0, Score: 0.00072
# Feature : 1, Score: 0.00062
# Feature : 2, Score: 0.02296
# Feature : 3, Score: 0.00077
# Feature : 4, Score: 0.00084
# Feature : 5, Score: 0.00031
# Feature : 6, Score: 0.00480
# Feature : 7, Score: 0.00427
# Feature : 8, Score: 0.00161
# Feature : 9, Score: 0.00482
# Feature : 10, Score: 0.00135
# Feature : 11, Score: 0.00760
# Feature : 12, Score: 0.00104
# Feature : 13, Score: 0.00144
# Feature : 14, Score: 0.00533
# Feature : 15, Score: 0.00320
# Feature : 16, Score: 0.00028
# Feature : 17, Score: 0.00067
# Feature : 18, Score: 0.00201
# Feature : 19, Score: 0.00418
# Feature : 20, Score: 0.00378
# Feature : 21, Score: 0.00386
# Feature : 22, Score: 0.00082
# Feature : 23, Score: 0.00326
# Feature : 24, Score: 0.00668
# Feature : 25, Score: 0.13351
# Feature : 26, Score: 0.00526
# Feature : 27, Score: 0.75052
# Feature : 28, Score: 0.00184
# Feature : 29, Score: 0.00056
# Feature : 30, Score: 0.00059
# ...

# %%
from sklearn.ensemble import RandomForestRegressor
modelRFC1=RandomForestRegressor()
modelRFC1.fit(train_X1,train_Y1)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
#get importance
impRFC_1 = modelRFC1.feature_importances_
print("importances feature Data")
for i,v in enumerate(impRFC_1):
  print("Feature : %0d, Score: %.5f" % (i,v))
# Out:
# importances feature Data
# Feature : 0, Score: 0.00917
# Feature : 1, Score: 0.02095
# Feature : 2, Score: 0.04359
# Feature : 3, Score: 0.00999
# Feature : 4, Score: 0.01475
# Feature : 5, Score: 0.01042
# Feature : 6, Score: 0.03994
# Feature : 7, Score: 0.02786
# Feature : 8, Score: 0.01699
# Feature : 9, Score: 0.03194
# Feature : 10, Score: 0.11644
# Feature : 11, Score: 0.01720
# Feature : 12, Score: 0.01418
# Feature : 13, Score: 0.01072
# Feature : 14, Score: 0.01630
# Feature : 15, Score: 0.01061
# Feature : 16, Score: 0.01680
# Feature : 17, Score: 0.00539
# Feature : 18, Score: 0.01497
# Feature : 19, Score: 0.02165
# Feature : 20, Score: 0.04349
# Feature : 21, Score: 0.05010
# Feature : 22, Score: 0.01264
# Feature : 23, Score: 0.02693
# Feature : 24, Score: 0.03774
# Feature : 25, Score: 0.18147
# Feature : 26, Score: 0.01857
# Feature : 27, Score: 0.00657
# Feature : 28, Score: 0.00867
# Feature : 29, Score: 0.02808
# Feature : 30, Score: 0.00745
# ...

# %%
from sklearn.ensemble import RandomForestRegressor
modelRFC2=RandomForestRegressor()
modelRFC2.fit(train_X2,train_Y2)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
#get importance
impRFC_2 = modelRFC2.feature_importances_
print("importances feature Data")
for i,v in enumerate(impRFC_2):
  print("Feature : %0d, Score: %.5f" % (i,v))
# Out:
# importances feature Data
# Feature : 0, Score: 0.00114
# Feature : 1, Score: 0.00049
# Feature : 2, Score: 0.01985
# Feature : 3, Score: 0.00091
# Feature : 4, Score: 0.00065
# Feature : 5, Score: 0.00109
# Feature : 6, Score: 0.00405
# Feature : 7, Score: 0.00488
# Feature : 8, Score: 0.00195
# Feature : 9, Score: 0.00609
# Feature : 10, Score: 0.00190
# Feature : 11, Score: 0.00405
# Feature : 12, Score: 0.00100
# Feature : 13, Score: 0.00254
# Feature : 14, Score: 0.00590
# Feature : 15, Score: 0.00217
# Feature : 16, Score: 0.00038
# Feature : 17, Score: 0.00062
# Feature : 18, Score: 0.00128
# Feature : 19, Score: 0.00386
# Feature : 20, Score: 0.00321
# Feature : 21, Score: 0.00432
# Feature : 22, Score: 0.00120
# Feature : 23, Score: 0.00256
# Feature : 24, Score: 0.00871
# Feature : 25, Score: 0.13076
# Feature : 26, Score: 0.76139
# Feature : 27, Score: 0.00159
# Feature : 28, Score: 0.00046
# Feature : 29, Score: 0.00092
# Feature : 30, Score: 0.00155
# ...

# %%
from sklearn.ensemble import RandomForestRegressor
modelRFC3=RandomForestRegressor()
modelRFC3.fit(train_X3,train_Y3)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
#get importance
impRFC_3 = modelRFC3.feature_importances_
print("importances feature Data")
for i,v in enumerate(impRFC_3):
  print("Feature : %0d, Score: %.5f" % (i,v))
# Out:
# importances feature Data
# Feature : 0, Score: 0.00185
# Feature : 1, Score: 0.00125
# Feature : 2, Score: 0.03334
# Feature : 3, Score: 0.00269
# Feature : 4, Score: 0.00199
# Feature : 5, Score: 0.00114
# Feature : 6, Score: 0.01186
# Feature : 7, Score: 0.00870
# Feature : 8, Score: 0.00338
# Feature : 9, Score: 0.00552
# Feature : 10, Score: 0.00559
# Feature : 11, Score: 0.02425
# Feature : 12, Score: 0.00227
# Feature : 13, Score: 0.00702
# Feature : 14, Score: 0.00765
# Feature : 15, Score: 0.00190
# Feature : 16, Score: 0.00075
# Feature : 17, Score: 0.00262
# Feature : 18, Score: 0.00459
# Feature : 19, Score: 0.00818
# Feature : 20, Score: 0.00567
# Feature : 21, Score: 0.00956
# Feature : 22, Score: 0.00257
# Feature : 23, Score: 0.00772
# Feature : 24, Score: 0.00964
# Feature : 25, Score: 0.17502
# Feature : 26, Score: 0.61504
# Feature : 27, Score: 0.00577
# Feature : 28, Score: 0.00095
# Feature : 29, Score: 0.00267
# Feature : 30, Score: 0.00438
# ...

# %%
predRFC_train=modelRFC.predict(train_X)
predRFC_train_1=modelRFC1.predict(train_X1)
predRFC_train_2=modelRFC2.predict(train_X2)
predRFC_train_3=modelRFC3.predict(train_X3)

# %%
RMSE_trainRFC = np.sqrt(np.mean(pow((predRFC_train) - (train_Y),2)))
RMSE_trainRFC1 = np.sqrt(np.mean(pow((predRFC_train_1) - (train_Y1),2)))
RMSE_trainRFC2 = np.sqrt(np.mean(pow((predRFC_train_2) - (train_Y2),2)))
RMSE_trainRFC3 = np.sqrt(np.mean(pow((predRFC_train_3) - (train_Y3),2)))

print("RMSE data train =", RMSE_trainRFC)
print("RMSE data_1 train =", RMSE_trainRFC1)
print("RMSE data_2 train =", RMSE_trainRFC2)
print("RMSE data_3 train =", RMSE_trainRFC3)
# Out:
# RMSE data train = 0.6253477513564616
# RMSE data_1 train = 1.5157661930188095
# RMSE data_2 train = 0.6494844596225064
# RMSE data_3 train = 0.7996065092407973

# %%
predRFC=modelRFC.predict(test_X)
predRFC_1=modelRFC1.predict(test_X1)
predRFC_2=modelRFC2.predict(test_X2)
predRFC_3=modelRFC3.predict(test_X3)

# %%
RMSE_testRFC = np.sqrt(np.mean(pow((predRFC) - (test_Y),2)))
RMSE_testRFC1 = np.sqrt(np.mean(pow((predRFC_1) - (test_Y1),2)))
RMSE_testRFC2 = np.sqrt(np.mean(pow((predRFC_2) - (test_Y2),2)))
RMSE_testRFC3 = np.sqrt(np.mean(pow((predRFC_3) - (test_Y3),2)))

print("RMSE data test =", RMSE_testRFC)
print("RMSE data_1 test =", RMSE_testRFC1)
print("RMSE data_2 test =", RMSE_testRFC2)
print("RMSE data_3 test =", RMSE_testRFC3)
# Out:
# RMSE data test = 1.4984291352672376
# RMSE data_1 test = 3.3224956305749864
# RMSE data_2 test = 1.4502723445676404
# RMSE data_3 test = 2.9317165663338702

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor
modelDT=DecisionTreeRegressor()
modelDT.fit(train_X,train_Y)

#get importance
impDT = modelDT.feature_importances_
print("importances feature Data")
for i,v in enumerate(impDT):
  print("Feature : %0d, Score: %.5f" % (i,v))
# Out:
# importances feature Data
# Feature : 0, Score: 0.00000
# Feature : 1, Score: 0.00015
# Feature : 2, Score: 0.03477
# Feature : 3, Score: 0.00065
# Feature : 4, Score: 0.00011
# Feature : 5, Score: 0.00000
# Feature : 6, Score: 0.00038
# Feature : 7, Score: 0.01053
# Feature : 8, Score: 0.00091
# Feature : 9, Score: 0.00076
# Feature : 10, Score: 0.00079
# Feature : 11, Score: 0.01028
# Feature : 12, Score: 0.00053
# Feature : 13, Score: 0.00000
# Feature : 14, Score: 0.00000
# Feature : 15, Score: 0.00080
# Feature : 16, Score: 0.00000
# Feature : 17, Score: 0.00037
# Feature : 18, Score: 0.00010
# Feature : 19, Score: 0.00050
# Feature : 20, Score: 0.00075
# Feature : 21, Score: 0.00096
# Feature : 22, Score: 0.00012
# Feature : 23, Score: 0.00738
# Feature : 24, Score: 0.01521
# Feature : 25, Score: 0.14853
# Feature : 26, Score: 0.01541
# Feature : 27, Score: 0.73197
# Feature : 28, Score: 0.00082
# Feature : 29, Score: 0.00021
# Feature : 30, Score: 0.00000
# ...

# %%
from sklearn.tree import DecisionTreeRegressor
modelDT=DecisionTreeRegressor()
modelDT.fit(train_X,train_Y)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best')

# %%
from sklearn.tree import DecisionTreeRegressor
modelDT1=DecisionTreeRegressor()
modelDT1.fit(train_X1,train_Y1)

#get importance
impDT_1 = modelDT1.feature_importances_
print("importances feature Data")
for i,v in enumerate(impDT_1):
  print("Feature : %0d, Score: %.5f" % (i,v))
# Out:
# importances feature Data
# Feature : 0, Score: 0.06027
# Feature : 1, Score: 0.01820
# Feature : 2, Score: 0.04818
# Feature : 3, Score: 0.02309
# Feature : 4, Score: 0.01106
# Feature : 5, Score: 0.00000
# Feature : 6, Score: 0.04213
# Feature : 7, Score: 0.02708
# Feature : 8, Score: 0.00633
# Feature : 9, Score: 0.02907
# Feature : 10, Score: 0.11411
# Feature : 11, Score: 0.02468
# Feature : 12, Score: 0.00390
# Feature : 13, Score: 0.01687
# Feature : 14, Score: 0.00339
# Feature : 15, Score: 0.01801
# Feature : 16, Score: 0.02819
# Feature : 17, Score: 0.00010
# Feature : 18, Score: 0.00360
# Feature : 19, Score: 0.00604
# Feature : 20, Score: 0.01648
# Feature : 21, Score: 0.00410
# Feature : 22, Score: 0.00876
# Feature : 23, Score: 0.02913
# Feature : 24, Score: 0.03222
# Feature : 25, Score: 0.15997
# Feature : 26, Score: 0.02083
# Feature : 27, Score: 0.00029
# Feature : 28, Score: 0.00937
# Feature : 29, Score: 0.02756
# Feature : 30, Score: 0.00891
# ...

# %%
from sklearn.tree import DecisionTreeRegressor
modelDT2=DecisionTreeRegressor()
modelDT2.fit(train_X2,train_Y2)

#get importance
impDT_2 = modelDT.feature_importances_
print("importances feature Data")
for i,v in enumerate(impDT_2):
  print("Feature : %0d, Score: %.5f" % (i,v))
# Out:
# importances feature Data
# Feature : 0, Score: 0.00000
# Feature : 1, Score: 0.00015
# Feature : 2, Score: 0.03477
# Feature : 3, Score: 0.00065
# Feature : 4, Score: 0.00011
# Feature : 5, Score: 0.00000
# Feature : 6, Score: 0.00038
# Feature : 7, Score: 0.01053
# Feature : 8, Score: 0.00091
# Feature : 9, Score: 0.00076
# Feature : 10, Score: 0.00079
# Feature : 11, Score: 0.01028
# Feature : 12, Score: 0.00053
# Feature : 13, Score: 0.00000
# Feature : 14, Score: 0.00000
# Feature : 15, Score: 0.00080
# Feature : 16, Score: 0.00000
# Feature : 17, Score: 0.00037
# Feature : 18, Score: 0.00010
# Feature : 19, Score: 0.00050
# Feature : 20, Score: 0.00075
# Feature : 21, Score: 0.00096
# Feature : 22, Score: 0.00012
# Feature : 23, Score: 0.00738
# Feature : 24, Score: 0.01521
# Feature : 25, Score: 0.14853
# Feature : 26, Score: 0.01541
# Feature : 27, Score: 0.73197
# Feature : 28, Score: 0.00082
# Feature : 29, Score: 0.00021
# Feature : 30, Score: 0.00000
# ...

# %%
from sklearn.tree import DecisionTreeRegressor
modelDT3=DecisionTreeRegressor()
modelDT3.fit(train_X3,train_Y3)

#get importance
impDT_3 = modelDT.feature_importances_
print("importances feature Data")
for i,v in enumerate(impDT_3):
  print("Feature : %0d, Score: %.5f" % (i,v))
# Out:
# importances feature Data
# Feature : 0, Score: 0.00000
# Feature : 1, Score: 0.00015
# Feature : 2, Score: 0.03477
# Feature : 3, Score: 0.00065
# Feature : 4, Score: 0.00011
# Feature : 5, Score: 0.00000
# Feature : 6, Score: 0.00038
# Feature : 7, Score: 0.01053
# Feature : 8, Score: 0.00091
# Feature : 9, Score: 0.00076
# Feature : 10, Score: 0.00079
# Feature : 11, Score: 0.01028
# Feature : 12, Score: 0.00053
# Feature : 13, Score: 0.00000
# Feature : 14, Score: 0.00000
# Feature : 15, Score: 0.00080
# Feature : 16, Score: 0.00000
# Feature : 17, Score: 0.00037
# Feature : 18, Score: 0.00010
# Feature : 19, Score: 0.00050
# Feature : 20, Score: 0.00075
# Feature : 21, Score: 0.00096
# Feature : 22, Score: 0.00012
# Feature : 23, Score: 0.00738
# Feature : 24, Score: 0.01521
# Feature : 25, Score: 0.14853
# Feature : 26, Score: 0.01541
# Feature : 27, Score: 0.73197
# Feature : 28, Score: 0.00082
# Feature : 29, Score: 0.00021
# Feature : 30, Score: 0.00000
# ...

# %%
predDT_train=modelDT.predict(train_X)
predDT_train_1=modelDT1.predict(train_X1)
predDT_train_2=modelDT2.predict(train_X2)
predDT_train_3=modelDT3.predict(train_X3)

RMSE_trainDT = np.sqrt(np.mean(pow((predDT_train) - (train_Y),2)))
RMSE_trainDT1 = np.sqrt(np.mean(pow((predDT_train_1) - (train_Y1),2)))
RMSE_trainDT2 = np.sqrt(np.mean(pow((predDT_train_2) - (train_Y2),2)))
RMSE_trainDT3 = np.sqrt(np.mean(pow((predDT_train_3) - (train_Y3),2)))

print("RMSE data train =", RMSE_trainDT)
print("RMSE data_1 train =", RMSE_trainDT1)
print("RMSE data_2 train =", RMSE_trainDT2)
print("RMSE data_3 train =", RMSE_trainDT3)
# Out:
# RMSE data train = 0.0
# RMSE data_1 train = 0.0
# RMSE data_2 train = 0.0
# RMSE data_3 train = 0.0

# %%
predDT_test=modelDT.predict(test_X)
predDT_test_1=modelDT1.predict(test_X1)
predDT_test_2=modelDT2.predict(test_X2)
predDT_test_3=modelDT3.predict(test_X3)

RMSE_testDT = np.sqrt(np.mean(pow((predDT_test) - (test_Y),2)))
RMSE_testDT1 = np.sqrt(np.mean(pow((predDT_test_1) - (test_Y1),2)))
RMSE_testDT2 = np.sqrt(np.mean(pow((predDT_test_2) - (test_Y2),2)))
RMSE_testDT3 = np.sqrt(np.mean(pow((predDT_test_3) - (test_Y3),2)))

print("RMSE data test =", RMSE_testDT)
print("RMSE data_1 test =", RMSE_testDT1)
print("RMSE data_2 test =", RMSE_testDT2)
print("RMSE data_3 test =", RMSE_testDT3)
# Out:
# RMSE data test = 2.3330319274891083
# RMSE data_1 test = 5.37457681584021
# RMSE data_2 test = 2.2332357180002065
# RMSE data_3 test = 3.7954002807529066

# %% [markdown]
# # SVM

# %%
from sklearn import svm
modelSVM = svm.SVC(kernel='linear') 
modelSVM.fit(train_X,train_Y)

modelSVM1 = svm.SVC(kernel='linear') 
modelSVM1.fit(train_X1,train_Y1)

modelSVM2 = svm.SVC(kernel='linear') 
modelSVM2.fit(train_X2,train_Y2)

modelSVM3 = svm.SVC(kernel='linear') 
modelSVM3.fit(train_X3,train_Y3)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='linear',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
from sklearn import svm
modelSVM = svm.SVC(kernel='linear') 
modelSVM.fit(train_X,train_Y)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='linear',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
predSVM_train=modelSVM.predict(train_X)
predSVM_train_1=modelSVM1.predict(train_X1)
predSVM_train_2=modelSVM2.predict(train_X2)
predSVM_train_3=modelSVM3.predict(train_X3)

RMSE_trainSVM = np.sqrt(np.mean(pow((predSVM_train) - (train_Y),2)))
RMSE_trainSVM1 = np.sqrt(np.mean(pow((predSVM_train_1) - (train_Y1),2)))
RMSE_trainSVM2 = np.sqrt(np.mean(pow((predSVM_train_2) - (train_Y2),2)))
RMSE_trainSVM3 = np.sqrt(np.mean(pow((predSVM_train_3) - (train_Y3),2)))

print("RMSE data train =", RMSE_trainSVM)
print("RMSE data_1 train =", RMSE_trainSVM1)
print("RMSE data_2 train =", RMSE_trainSVM2)
print("RMSE data_3 train =", RMSE_trainSVM3)
# Out:
# RMSE data train = 0.21048467276349228
# RMSE data_1 train = 1.5700923136611176
# RMSE data_2 train = 0.24520722313684198
# RMSE data_3 train = 0.6608395121052415

# %%
predSVM_test=modelSVM.predict(test_X)
predSVM_test_1=modelSVM1.predict(test_X1)
predSVM_test_2=modelSVM2.predict(test_X2)
predSVM_test_3=modelSVM3.predict(test_X3)

RMSE_testSVM = np.sqrt(np.mean(pow((predSVM_test) - (test_Y),2)))
RMSE_testSVM1 = np.sqrt(np.mean(pow((predSVM_test_1) - (test_Y1),2)))
RMSE_testSVM2 = np.sqrt(np.mean(pow((predSVM_test_2) - (test_Y2),2)))
RMSE_testSVM3 = np.sqrt(np.mean(pow((predSVM_test_3) - (test_Y3),2)))

print("RMSE data test =", RMSE_testSVM)
print("RMSE data_1 test =", RMSE_testSVM1)
print("RMSE data_2 test =", RMSE_testSVM2)
print("RMSE data_3 test =", RMSE_testSVM3)
# Out:
# RMSE data test = 1.0125791108334214
# RMSE data_1 test = 5.037831560844709
# RMSE data_2 test = 1.4755389489516764
# RMSE data_3 test = 3.0335674783280524

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsRegressor
modelKNN = KNeighborsRegressor()
modelKNN.fit(train_X,train_Y)

modelKNN1 = KNeighborsRegressor()
modelKNN1.fit(train_X1,train_Y1)

modelKNN2 = KNeighborsRegressor()
modelKNN2.fit(train_X2,train_Y2)

modelKNN3 = KNeighborsRegressor()
modelKNN3.fit(train_X3,train_Y3)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                     weights='uniform')

# %%
import numpy as np
predKNN_train=modelKNN.predict(train_X)
predKNN_train_1=modelKNN1.predict(train_X1)
predKNN_train_2=modelKNN2.predict(train_X2)
predKNN_train_3=modelKNN3.predict(train_X3)

RMSE_trainKNN = np.sqrt(np.mean(pow((predKNN_train) - (train_Y),2)))
RMSE_trainKNN1 = np.sqrt(np.mean(pow((predKNN_train_1) - (train_Y1),2)))
RMSE_trainKNN2 = np.sqrt(np.mean(pow((predKNN_train_2) - (train_Y2),2)))
RMSE_trainKNN3 = np.sqrt(np.mean(pow((predKNN_train_3) - (train_Y3),2)))

print("RMSE data train =", RMSE_trainKNN)
print("RMSE data_1 train =", RMSE_trainKNN1)
print("RMSE data_2 train =", RMSE_trainKNN2)
print("RMSE data_3 train =", RMSE_trainKNN3)
# Out:
# RMSE data train = 1.513441881643932
# RMSE data_1 train = 3.6679591124538056
# RMSE data_2 train = 1.5197434826853378
# RMSE data_3 train = 2.0815342442839095

# %%
import numpy as np
predKNN_test=modelKNN.predict(test_X)
predKNN_test_1=modelKNN1.predict(test_X1)
predKNN_test_2=modelKNN2.predict(test_X2)
predKNN_test_3=modelKNN3.predict(test_X3)

RMSE_testKNN = np.sqrt(np.mean(pow((predKNN_test) - (test_Y),2)))
RMSE_testKNN1 = np.sqrt(np.mean(pow((predKNN_test_1) - (test_Y1),2)))
RMSE_testKNN2 = np.sqrt(np.mean(pow((predKNN_test_2) - (test_Y2),2)))
RMSE_testKNN3 = np.sqrt(np.mean(pow((predKNN_test_3) - (test_Y3),2)))

print("RMSE data test =", RMSE_testKNN)
print("RMSE data_1 test =", RMSE_testKNN1)
print("RMSE data_2 test =", RMSE_testKNN2)
print("RMSE data_3 test =", RMSE_testKNN3)
# Out:
# RMSE data test = 1.7826164811835838
# RMSE data_1 test = 3.577142626047864
# RMSE data_2 test = 1.6817712182041131
# RMSE data_3 test = 2.5740673621352896
